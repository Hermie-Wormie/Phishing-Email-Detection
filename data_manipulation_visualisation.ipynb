# %%
# must run

import os
from nltk import download
from main import extract_data, read_cleandata
from DATAMANIPULATION.data_clean import dataset_cleaning
from DATAMANIPULATION.data_analysis import *

os.environ['LOKY_MAX_CPU_COUNT'] = '16'

# %%
# only run if u installed nltk for the first time

download('punkt_tab')
download('stopwords')
download('averaged_perceptron_tagger_eng')
download('wordnet')
download('omw-1.4')
download('vader_lexicon')

# %%
# if u dont want to wait 12 mins, and there is data in data-1.csv and data-2.csv, DO NOT run this
# it's only going to waste ur time :)

dataset_cleaning(extract_data())

# %%
# testing data analysis

cdf = read_files(read_cleandata())
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82486 entries, 0 to 82485
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sender   49529 non-null  object
#  1   date     49377 non-null  object
#  2   subject  80965 non-null  object
#  3   body     82411 non-null  object
#  4   url      32666 non-null  object
#  5   label    82486 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 3.8+ MB

# %%
# show the first 5 of combined cleaned dataset

cdf.head()
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                 Michael Parker <ivqrnai@pobox.com>
# 4  Gretchen Suggs <externalsep1@loanofficertool.com>
#
#                               date                     subject  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700           never agree loser
# 1  Tue, 05 Aug 2008 18:31:03 -0500      befriend jenna jameson
# 2  Tue, 05 Aug 2008 20:28:00 -1200                daily top 10
# 3  Tue, 05 Aug 2008 17:31:20 -0600          svn commit r619753
# 4  Tue, 05 Aug 2008 19:31:21 -0400  specialpricespharmmoreinfo
#
#                                                 body  \
# 0  buck trouble cause small dimension soon become...
# 1                     upgrade sex pleasure technique
# 2  daily top 10 top video story aug 1 2008 pm edt...
# 3  would anyone object remove list tld basically ...
# 4                 welcomefastshippingcustomersupport
#
#                                                  url  label
# 0                              http://whitedone.com/      1
# 1                          http://www.brightmade.com      1
# 2  http://www.cnn.com/video/partners/email/index....      1
# 3  http://en.wikipedia.org/wiki/.so_%28domain_nam...      0
# 4  http://7iwfna.blu.livefilestore.com/y1pXdX3kwz...      1

# %%
# test distribution of label (phishing or not)

label_distrbution(cdf.copy())

# %%
# test sender domain count

sender_domain(cdf.copy())

# %%
# test feature frequency

feature_frequency(cdf.copy())

# %%
# test time count

time_count(cdf.copy())

# %%
# test sentiment analysis

sentiment_analysis(cdf.copy())

# %%
# test sentiment analysis 2.0

visualise_sentiment2(cdf.copy())
