# %%
# must run

import os
from nltk import download
from main import extract_data, read_cleandata
from DATAMANIPULATION.data_clean import dataset_cleaning
from DATAMANIPULATION.data_analysis import *

os.environ['LOKY_MAX_CPU_COUNT'] = '16'

# %%
# only run if u installed nltk for the first time

download('punkt_tab')
download('stopwords')
download('averaged_perceptron_tagger_eng')
download('wordnet')
download('omw-1.4')
download('vader_lexicon')

# %%
# if u dont want to wait 12 mins, and there is data in data-1.csv and data-2.csv, DO NOT run this
# it's only going to waste ur time :)

dataset_cleaning(extract_data())

# %%
# testing data analysis

cdf = read_files(read_cleandata())
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82486 entries, 0 to 82485
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sender   49529 non-null  object
#  1   date     49377 non-null  object
#  2   subject  80965 non-null  object
#  3   body     82411 non-null  object
#  4   url      32666 non-null  object
#  5   label    82486 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 3.8+ MB

# %%
# show the first 10 of combined cleaned dataset

cdf.head(10)

# %%
# test distribution of label (phishing or not)

label_distrbution(cdf.copy())

# %%
# test sender domain count

sender_domain(cdf.copy())

# %%
# test email body length 

email_content_length(cdf.copy())

# %%
# test feature frequency

feature_frequency(cdf.copy())

# %%
# test link analysis (some errors)

link_analysis(cdf.copy())

# %%
# test time count

time_count(cdf.copy())

# %%
# test sentiment analysis

sentiment_analysis(cdf.copy())

# %%
# test sentiment analysis 2.0

visualise_sentiment2(cdf.copy())
